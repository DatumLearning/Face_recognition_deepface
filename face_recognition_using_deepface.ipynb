# %% [markdown]
# <a href="https://colab.research.google.com/github/DatumLearning/Face_recognition_deepface/blob/main/face_recognition_using_deepface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface -q

# %%
from deepface import DeepFace
import cv2
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
out1 = DeepFace.verify("/content/modi1.jpg" , "/content/modi2.jpg")

# %%
out2 = DeepFace.verify("/content/modi1.jpg" , "/content/trump.jpg")

# %%
out1
# Out:
# {'verified': True,
#  'distance': 0.14591425721930695,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 171, 'y': 99, 'w': 186, 'h': 186},
#   'img2': {'x': 97, 'y': 74, 'w': 234, 'h': 234}},
#  'time': 59.92}

# %%
x , y , w , h = out1["facial_areas"]["img1"].values()

# %%
x , y , w , h
# Out:
# (171, 99, 186, 186)

# %%
ig = cv2.imread("/content/modi1.jpg")
ig = cv2.rectangle(ig , (x , y) , (x + w , y + h) , (0 , 0 , 255) , 3)
cv2_imshow(ig)
# Out:
# <PIL.Image.Image image mode=RGB size=474x608 at 0x7F16298BCD60>

# %%
out3 = DeepFace.find("/content/modi1.jpg" , "/content/fold")
# Out:
# Finding representations: 100%|██████████| 2/2 [00:01<00:00,  1.41it/s]
# Representations stored in  /content/fold / representations_vgg_face.pkl  file. Please delete this file when you add new identities in your database.
# find function lasts  2.232069969177246  seconds

# %%
out3[0]
# Out:
#                   identity  source_x  source_y  source_w  source_h  \
# 0  /content/fold/modi2.jpg       171        99       186       186
#
#    VGG-Face_cosine
# 0         0.145914
